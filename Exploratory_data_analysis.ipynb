# %% [markdown]
# <a href="https://colab.research.google.com/github/MrunmayiThombare/DSAI-workshop/blob/main/Exploratory_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([3, 12, 16, 33, 45, 49, 57, 71, 73, 80])
y = np.array([7, 11, 19, 24, 21, 45, 56, 78, 87,89])
z = np.array([7, 71, 56, 54, 44, 34, 32, 26, 21, 8])
p = np.array([55, 57, 67, 72, 55, 53, 45, 49, 76, 45])

plt.plot(x, y, label='y')

plt.show()

# %%
plt.plot(x,z)

# %%
plt.plot(x,p)

# %%
plt.plot(y,z)

# %%
plt.title('My first graph')
plt.xlabel('First value')
plt.ylabel('Second value')
plt.grid()
plt.xticks(range(0,91,5))
plt.yticks(range(0,91,5))
plt.xlim(0,90)
plt.ylim(0,90)
plt.plot(x,y)

# %%
plt.title('My first graph')
plt.xlabel('First value')
plt.ylabel('Second value')
plt.grid()
plt.xticks(range(0,91,5))
plt.yticks(range(0,91,5))
plt.xlim(0,90)
plt.ylim(0,90)
plt.plot(x,y,label = '2023')
plt.plot(y,z,label = '2024')
plt.legend();

# %%
plt.figure(figsize=(16,9))
plt.title('My first graph')
plt.xlabel('First value')
plt.ylabel('Second value')
plt.grid()
plt.plot(x,y,color= 'brown', marker = 'o')

# %%
plt.figure(figsize=(16,9))
plt.subplot(2,1,1)
plt.plot(x,y)
plt.subplot(1,2,1)
plt.plot(x,z)
# Out:
# <ipython-input-24-db860e6b206c>:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1,2,1)

# %%
plt.figure(figsize=(16,9))
plt.subplot(2,1,1)
plt.plot(x,y)
plt.subplot(1,2,1)
plt.plot(x,z)

# %%
df=pd.read_csv('student.csv')
plt.plot(df['age'],df['marks'])

# %%
plt.scatter(x,y)

# %%
df = pd.read_csv('Social_Network_Ads.csv')
print(df)
# Out:
#       User ID  Gender   Age  EstimatedSalary  Purchased
# 0    15624510    Male  19.0          19000.0          0
# 1    15810944    Male  35.0          20000.0          0
# 2    15668575  Female  26.0          43000.0          0
# 3    15603246  Female  27.0          57000.0          0
# 4    15804002    Male  19.0          76000.0          0
# ..        ...     ...   ...              ...        ...
# 395  15691863  Female  46.0          41000.0          1
# 396  15706071    Male  51.0          23000.0          1
# 397  15654296  Female  50.0          20000.0          1
# 398  15755018    Male  36.0          33000.0          0
# 399  15594041  Female  49.0          36000.0          1
#
# [400 rows x 5 columns]

# %%
plt.figure(figsize=(16,9))
plt.title('Scatter plot')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.grid()
plt.scatter(df["Age"],df['EstimatedSalary'],c=df['Purchased'])

# %%
df = pd.read_csv('student.csv')
plt.figure(figsize=(16,9))
plt.grid();
plt.xlabel("Student name")
plt.ylabel("Marks")
plt.bar(df['name'],df['marks'],color = 'pink')
# Out:
# <BarContainer object of 10 artists>

# %%
df['age'].value_counts()
# Out:
# 20    4
# 21    2
# 19    2
# 22    1
# 23    1
# Name: age, dtype: int64

# %%
plt.grid();
plt.xlabel("Age")
plt.ylabel("Count")
plt.bar(df['age'].value_counts().index ,df['age'].value_counts(),color = 'pink')
# Out:
# <BarContainer object of 5 artists>

# %%
plt.grid();
plt.xlabel("Student name")

plt.ylabel("Marks")
plt.barh(df['name'],df['marks'],color = 'pink')
# Out:
# <BarContainer object of 10 artists>

# %%
df = pd.read_csv('Social_Network_Ads.csv')
plt.xlabel("Age")
plt.ylabel("Count")
plt.bar(df['Purchased'].value_counts().index ,df['Purchased'].value_counts(),color = 'pink')
# Out:
# <BarContainer object of 2 artists>

# %%
plt.pie(df['Purchased'].value_counts(),
        labels=df['Purchased'].value_counts().index, autopct = '%2.2f%%');

# %%
plt.pie(df['Gender'].value_counts(),
        labels=df['Gender'].value_counts().index, autopct = '%2.2f%%');

# %%
plt.xlabel('Ages')
plt.ylabel('Count')
plt.grid()
plt.xticks(range(10,61,10))
plt.hist(df['Age'] ,bins=range(10,61,10),color='pink');

# %%
plt.boxplot(df['Age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7955d8126f50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7955dc8281f0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7955d8126b90>],
#  'medians': [<matplotlib.lines.Line2D at 0x7955d82d59c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7955d82d61d0>],
#  'means': []}

# %%
df.loc[156,'Age']
# Out:
# 46.0

# %%
df.loc[156,'Age']=69
print(df)
# Out:
#       User ID  Gender   Age  EstimatedSalary  Purchased
# 0    15624510    Male  19.0          19000.0          0
# 1    15810944    Male  35.0          20000.0          0
# 2    15668575  Female  26.0          43000.0          0
# 3    15603246  Female  27.0          57000.0          0
# 4    15804002    Male  19.0          76000.0          0
# ..        ...     ...   ...              ...        ...
# 395  15691863  Female  46.0          41000.0          1
# 396  15706071    Male  51.0          23000.0          1
# 397  15654296  Female  50.0          20000.0          1
# 398  15755018    Male  36.0          33000.0          0
# 399  15594041  Female  49.0          36000.0          1
#
# [400 rows x 5 columns]

# %%
plt.boxplot(df['Age']);

# %%
x=df[(df['Age']>5)&(df['Age']<64)]
x.shape
# Out:
# (399, 5)

# %%
import seaborn as sns
df = pd.read_csv('Social_Network_Ads.csv')
sns.jointplot(x='Age' , y = 'EstimatedSalary' , data = df , hue = 'Purchased')

# %%
iris = sns.load_dataset('iris')
print(iris)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(iris)

# %%
sns.pairplot(iris , hue='species')

# %%
titanic = sns.load_dataset('titanic')
print(titanic)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.countplot(titanic['sex'])
# Out:
# <Axes: xlabel='count', ylabel='sex'>

# %%
sns.countplot(titanic['class'])
# Out:
# <Axes: xlabel='count', ylabel='class'>

# %%
sns.countplot(titanic['survived'])
# Out:
# <Axes: ylabel='count'>

# %%
sns.barplot(x='sex',y='survived', hue='class' , data=titanic )
# Out:
# <Axes: xlabel='sex', ylabel='survived'>
